# %% [markdown]
# <a href="https://colab.research.google.com/github/Mparimalaa/23CSBTB30/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
list = ["apple", "cherry", "rose"]
print(list)
# Out:
# ['apple', 'cherry', 'rose']
